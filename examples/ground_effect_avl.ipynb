# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt

# %%
import numpy as np

# %% [markdown]
# # Load Foil Data

# %%
from ICARUS.computation.solvers.XFLR5.polars import read_polars_2d
from ICARUS.database import DB
from ICARUS.core.struct import Struct
from ICARUS.database import EXTERNAL_DB

# %% [markdown]
# # Get Plane

# %%
from vehicles.Planes.box_wing_nondimensional import get_box_wing
airplane = get_box_wing(name = 'ge_box', AR=9, naca = "0012")

# %% [markdown]
# # Import Environment and Set State

# %%
from ICARUS.environment.definition import EARTH_ISA
from ICARUS.flight_dynamics.state import State

u_freestream = 20
unstick = State(
    name= "unstick",
    airplane= airplane,
    environment= EARTH_ISA,
    u_freestream= u_freestream
)

# %% [markdown]
# # Get Solver

# %%
from ICARUS.computation.solvers.AVL.avl import AVL
avl = AVL()
print(avl)
# Out:
# 3D VLM Solver AVL:
# Available Analyses Are:
# -------------------
# 0) Aiplane Polar Analysis
# 1) Dynamic Analysis

# %% [markdown]
# ## AoA Run

# %%
analysis: str = avl.get_analyses_names()[0]
print(f"Selecting Analysis: {analysis}")
avl.select_analysis(analysis)
# Out:
# Selecting Analysis: Aiplane Polar Analysis

# %%
options: Struct = avl.get_analysis_options(verbose=True)
solver_parameters: Struct = avl.get_solver_parameters(verbose=True)
# Out:
# Aiplane Polar Analysis
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                         | Description                                         |
# |-----------|-------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.0) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)    | State Object                                        |
# | solver2D  | Xfoil                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Available Solver Parameters of AVL for AVL:
#
# | VarName   | Value   | Description   |
# |-----------|---------|---------------|
#
# If there are multiple values you should inspect them sepretly by calling the option name

# %%
AoAmin = -6
AoAmax = 8
NoAoA = (AoAmax - AoAmin) + 1
angles = np.linspace(AoAmin, AoAmax, NoAoA, dtype= float)
# airplane.define_dynamic_pressure(u_freestream, EARTH.air_density)

options.plane         = airplane
options.state         = unstick
options.solver2D      = 'Xfoil'
options.angles        = angles

solver_parameters.inviscid = True

hs = np.linspace(0, 10*airplane.span, 100)

for h in hs:
    unstick.environment._set_altitude(h)
    airplane.name = f"ge_box_{h}"
    avl.define_analysis(options, solver_parameters)
    avl.print_analysis_options()
    avl.execute(parallel = False)
    polars = avl.get_results()
    airplane.save()
# Out:
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                         | Description                                         |
# |-----------|-------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.0) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)    | State Object                                        |
# | solver2D  | Xfoil                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                          | Description                                         |
# |-----------|------------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.020202020202020204) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                     | State Object                                        |
# | solver2D  | Xfoil                                          | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                               | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.04040404040404041) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.06060606060606061) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.08080808080808081) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.10101010101010102) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.12121212121212122) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.14141414141414144) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.16161616161616163) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.18181818181818182) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.20202020202020204) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.22222222222222224) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.24242424242424243) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.26262626262626265) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.2828282828282829) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.30303030303030304) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.32323232323232326) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.3434343434343435) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.36363636363636365) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.38383838383838387) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.4040404040404041) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.42424242424242425) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.4444444444444445) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.4646464646464647) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                         | Description                                         |
# |-----------|-----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.48484848484848486) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                    | State Object                                        |
# | solver2D  | Xfoil                                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.5050505050505051) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.5252525252525253) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.5454545454545455) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.5656565656565657) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.5858585858585859) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.6060606060606061) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.6262626262626263) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.6464646464646465) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.6666666666666667) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                       | Description                                         |
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.686868686868687) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.7070707070707072) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.7272727272727273) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.7474747474747475) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.7676767676767677) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                       | Description                                         |
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.787878787878788) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.8080808080808082) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.8282828282828284) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.8484848484848485) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.8686868686868687) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                       | Description                                         |
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.888888888888889) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.9090909090909092) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.9292929292929294) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.9494949494949496) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.9696969696969697) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                      | Description                                         |
# |-----------|--------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_0.98989898989899) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                 | State Object                                        |
# | solver2D  | Xfoil                                      | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                           | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# ...
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.676767676767677) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                       | Description                                         |
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.696969696969697) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.7171717171717173) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.7373737373737375) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.7575757575757578) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                       | Description                                         |
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.777777777777778) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.7979797979797982) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.8181818181818183) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.8383838383838385) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.8585858585858588) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                       | Description                                         |
# |-----------|---------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.878787878787879) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                  | State Object                                        |
# | solver2D  | Xfoil                                       | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                            | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.8989898989898992) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.9191919191919193) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.9393939393939394) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                        | Description                                         |
# |-----------|----------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.9595959595959598) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                   | State Object                                        |
# | solver2D  | Xfoil                                        | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                             | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                                      | Description                                         |
# |-----------|--------------------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_1.97979797979798) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)                 | State Object                                        |
# | solver2D  | Xfoil                                      | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype                           | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results
# Available Options of AVL for Aiplane Polar Analysis:
#
# | VarName   | Value                         | Description                                         |
# |-----------|-------------------------------|-----------------------------------------------------|
# | plane     | Complex Datatype (ge_box_2.0) | Vehicle Airplane Object                             |
# | state     | Complex Datatype (unstick)    | State Object                                        |
# | solver2D  | Xfoil                         | Name of 2D Solver from which to use computed polars |
# | angles    | Complex Datatype              | List of angles to run polars                        |
#
# If there are Multiple Values, or complex datatypes, or N/A you should inspect them sepretly by calling the option name
#
# Running Solver AVL:
# 	Analysis Aiplane Polar Analysis...
# Analysis Completed
# Getting Results

# %% [markdown]
# # Post Process

# %%
import matplotlib.pyplot as plt
from matplotlib import colors


cdict = {
    'red': ((0.0, 0.22, 0.0), (0.5, 1.0, 1.0), (1.0, 0.89, 1.0)),
    'green': ((0.0, 0.49, 0.0), (0.5, 1.0, 1.0), (1.0, 0.12, 1.0)),
    'blue': ((0.0, 0.72, 0.0), (0.5, 0.0, 0.0), (1.0, 0.11, 1.0)),
}

colors_ = colors.LinearSegmentedColormap('custom', cdict)


db3d = DB.vehicles_db
planenames: list[str] = db3d.get_planenames()
fig = plt.figure(figsize=(10,10))
axs = fig.subplots(2,1)  # type: ignore


axs[0].set_xlabel("h [m]")
axs[0].set_ylabel("CL")
axs[0].grid(True)

axs[1].set_xlabel("h [m]")
axs[1].set_ylabel("CD")
axs[1].grid(True)

polars = {}
for planename in planenames:
    if not planename.startswith("ge_box"):
        continue
    # Get h from the name
    h = float(planename.split("_")[-1])

    polar = DB.vehicles_db.polars[planename]
    # Get the dataframe where AoA is between -3 and 3
    polar = polar[(polar['AoA'] >= -3) & (polar['AoA'] <= 3)]

    polars[h] = (polar["AVL CL"], polar["AVL CD"], polar['AoA'])
    
# plot the polars in the same plot.
# We want the keys to be the x axis and the aoa values to be different lines
# For the first plot, we want the CL values
# For the second plot, we want the CD values
    
for i,(h, polar) in enumerate(polars.items()):
    if h == 0:
        h = "Infinity"
    else:
        h = f"{h:.4f}"
    axs[0].plot(polar[2], polar[0],color = colors_(i/len(polars.keys())) , label = f"h = {h} m")
    axs[1].plot(polar[2], polar[1],color = colors_(i/len(polars.keys())) , label = f"h = {h} m")

axs[0].legend()
